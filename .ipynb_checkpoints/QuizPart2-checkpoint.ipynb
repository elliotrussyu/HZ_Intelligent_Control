# %% [markdown]
# **Quiz Time**

# %% [markdown]
# *Question 1*
#
# Find the problems with this piece of code

# %%
def this_func(c, d) 
c += 1
d[0] = 3


a = 1
b = [1, 2]
this_func(a)
print(a, b)

# %% [markdown]
# *Question 2*
#
# What is being printed?

# %%
def this_func(c=0, d):
    c += 1
    d[0] = 3

a = 1
b = [1, 2]
this_func(b)
print(a, b)

# %% [markdown]
# *Question 3*
#
# What is being printed?

# %%
def this_func(c=0, d):
    c += 1
    d[0] = 3
    return c, d
a = 1
b = [1, 2]
print(this_func(a,b) )

# %% [markdown]
# *Question 4*
#
# The following strings:

# %%
print("abc\\")

# %%
print("abc//")

# %%
print("abc\/")

# %%
print("abc\\\")

# %% [markdown]
# *Question 5*
#
# Iterations

# %%
a = 1

while a > 0:
    a += 1
    print(a,end="\t")
    if a == 2:
        continue
    elif a == 5:
        break
    # else:
    #     pass

# %% [markdown]
# *Question 6*

# %%
listA[7]

# %% [markdown]
# *Question 7*

# %%
listA[:2] , listA[2:]

# %% [markdown]
# *Question 8*

# %%
listA[::-1]

# %% [markdown]
# *Question 9*

# %%
listA[1::2]

# %% [markdown]
# *Question 10*

# %%
listA[2] = listA[4]
print(listA)

# %% [markdown]
# *Question 11*

# %%
a, b = 1,3
listB = [a,b]
a = 7
print(listB)
# Out:
# [1, 3]

# %% [markdown]
# *Question 12*

# %%
listC = [0,0,0]
listC[0] = listB
print(listC)
# Out:
# [[1, 3], 0, 0]

# %% [markdown]
# *Question 13*

# %%
a, b = 1,3
listB = [a,b]
listC = [0,0,0]
listC[0] = listB
listD = listC[0]
listB.append(1000)
print(listD)
# Out:
# [1, 3, 1000]

# %% [markdown]
# *Question 14*

# %%
a = []
a.extend(3)

# %% [markdown]
# *Question 15*

# %%
d = "I"
e = "love"
f = "Python Programming"
g = d+e+f
print(g)

# %% [markdown]
# *Question 16*
#
# There are 2 variables: p, q.\
# p is given the value of 15.\
# q is given the value of 17.\
# These variables have already been defined.\
# I would like to switch the values such that\
# q is given the value of q \
# and q is given the value of p.

# %%
p = 15
q = 17

# %% [markdown]
# *Question 17*
#
# There is a program that should print *student name* and *student numbers* in the following format:
#
# You are *John Doe* and your student number is *000000*.
#
# The student name and student number is defined, complete the following code block.

# %%
stuName = 'Hanshu'
stuNum = 074968

# %% [markdown]
# *Question 18*
#
# If you don't remember what can you do with a Python data type, how should you seek for help when internet is unavailable?
